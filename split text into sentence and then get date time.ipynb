# %%
import datefinder
import pandas as pd

# %%
path = "CV_sample_test.xlsx"
wb_obj = openpyxl.load_workbook(path) 

sheet_obj = wb_obj.active 
cell_obj = sheet_obj.cell(row = 2, column = 2)

# %%
def text_to_sentences(text_content):
    text_string = text_content
    characters_to_replace = ["?", "\n", ","]
    
    for item in characters_to_replace:
        text_string = text_string.replace(item,".")
    sentences = text_string.split(".")
    
    j = 0
    for sentence in sentences:
        if len(sentence) < 1:
            continue
        elif sentence[0] == " ":
            sentence = sentence[1:]
            sentences[j] = sentence
            j += 1
        else:
            sentences[j] = sentence
            j += 1
    sentences = sentences[0:j]

    return(sentences)

# %%
def dates_in_sentences(sentences, print_sentence = True):
    if print_sentence == True:
        count = 0
        for sentence in sentences:
            for match in datefinder.find_dates(sentence):
                print("|DATETIME:|"+ str(match) + "|FULL_SENTENCE:|" + sentence + "\n")
    else:
        count = 0
        for sentence in sentences:
            for match in datefinder.find_dates(sentence):
                print("|DATETIME:|"+ str(match) + "\n")

# %%
#example functionality
dates_in_sentences(text_to_sentences(cell_obj.value), True)
# Out:
# |DATETIME:|2013-12-20 00:00:00|FULL_SENTENCE:|2013 – 2013 Minor Embedded Vision Design aan de Hogeschool van Arnhem en Nijmegen te Arnhem
#
# |DATETIME:|2014-12-20 00:00:00|FULL_SENTENCE:|2011 – 2014 HBO Embedded Systems Engineering aan de Hogeschool van Arnhem en Nijmegen te Arnhem
#
# |DATETIME:|2011-12-20 00:00:00|FULL_SENTENCE:|2008 – 2011 MBO ICT-Beheerder Niv
#
# |DATETIME:|2022-12-06 00:00:00|FULL_SENTENCE:|2022 Qt 6 Core Advanced with C++
#
# |DATETIME:|2022-12-06 00:00:00|FULL_SENTENCE:|2022 Qt 6 Core Intermediate with C++
#
# |DATETIME:|2022-12-06 00:00:00|FULL_SENTENCE:|2022 Qt 6 Core Beginners with C++
#
# |DATETIME:|2021-12-20 00:00:00|FULL_SENTENCE:|2021 Complete Python Developer 2021: Zero to Mastery
#
# |DATETIME:|2022-12-07 00:00:00|FULL_SENTENCE:|2015 Oracle Certified Associate (OCA): Java SE 7 Programmer
#
# |DATETIME:|2015-01-20 00:00:00|FULL_SENTENCE:|jan 2015 – heden CIMSOLUTIONS B
#
# |DATETIME:|2014-01-20 00:00:00|FULL_SENTENCE:|jan 2014 – jul 2014 EAL Apeldoorn B
#
# |DATETIME:|2014-07-20 00:00:00|FULL_SENTENCE:|jan 2014 – jul 2014 EAL Apeldoorn B
#
# |DATETIME:|2013-08-20 00:00:00|FULL_SENTENCE:|aug 2013 – dec 2014 DNVN    Software Engineer
#
# |DATETIME:|2014-12-20 00:00:00|FULL_SENTENCE:|aug 2013 – dec 2014 DNVN    Software Engineer
#
# |DATETIME:|2010-08-20 00:00:00|FULL_SENTENCE:|aug 2010 – feb 2011 AVOO    Software Engineer
#
# |DATETIME:|2011-02-20 00:00:00|FULL_SENTENCE:|aug 2010 – feb 2011 AVOO    Software Engineer
#
# |DATETIME:|2009-08-20 00:00:00|FULL_SENTENCE:|aug 2009 – feb 2010 Paradigit Computers B
#
# |DATETIME:|2010-02-20 00:00:00|FULL_SENTENCE:|aug 2009 – feb 2010 Paradigit Computers B
#
# |DATETIME:|2022-04-20 00:00:00|FULL_SENTENCE:| BRANCHE: Medisch PERIODE: april 2022 – nu
#
# |DATETIME:|2022-01-20 00:00:00|FULL_SENTENCE:| BRANCHE: Industrie  PERIODE: jan 2022 – april 2022
#
# |DATETIME:|2022-04-20 00:00:00|FULL_SENTENCE:| BRANCHE: Industrie  PERIODE: jan 2022 – april 2022
#
# |DATETIME:|2021-11-20 00:00:00|FULL_SENTENCE:| BRANCHE: Cosmetica/Consument PERIODE: nov 2021 – feb 2022
#
# |DATETIME:|2022-02-20 00:00:00|FULL_SENTENCE:| BRANCHE: Cosmetica/Consument PERIODE: nov 2021 – feb 2022
#
# |DATETIME:|2021-08-20 00:00:00|FULL_SENTENCE:| BRANCHE: Cosmetica/Consument PERIODE: aug 2021 – feb 2022
#
# |DATETIME:|2022-02-20 00:00:00|FULL_SENTENCE:| BRANCHE: Cosmetica/Consument PERIODE: aug 2021 – feb 2022
#
# |DATETIME:|2021-02-20 00:00:00|FULL_SENTENCE:| BRANCHE: Medisch  PERIODE: feb 2021 – aug 2021
#
# |DATETIME:|2021-08-20 00:00:00|FULL_SENTENCE:| BRANCHE: Medisch  PERIODE: feb 2021 – aug 2021
#
# |DATETIME:|2022-12-19 00:00:00|FULL_SENTENCE:|en wegens het COVID-19 virus is er besloten om er een software update van het apparaat te maken waarmee het COVID-19 virus kan worden gedetecteerd
#
# |DATETIME:|2022-12-19 00:00:00|FULL_SENTENCE:|en wegens het COVID-19 virus is er besloten om er een software update van het apparaat te maken waarmee het COVID-19 virus kan worden gedetecteerd
#
# |DATETIME:|2022-12-19 00:00:00|FULL_SENTENCE:|Implementeren algoritme COVID-19 in samenswerking met externe partij;
#
# |DATETIME:|2020-07-20 00:00:00|FULL_SENTENCE:| BRANCHE: Medisch PERIODE: jul 2020 – mrt 2021
#
# |DATETIME:|2018-01-20 00:00:00|FULL_SENTENCE:| BRANCHE: Medisch PERIODE: jan 2018 – jun 2020
#
# |DATETIME:|2020-06-20 00:00:00|FULL_SENTENCE:| BRANCHE: Medisch PERIODE: jan 2018 – jun 2020

# %%
#alternative
def dates_in_sentences2(sentences, print_sentence = True):
    if print_sentence == True:
        count = 0
        for sentence in sentences:
            for match in datefinder.find_dates(sentence):
                print_date = pd.to_datetime(pd.Series(match)).dt.strftime('%d/%m/%Y')
                print("|DATETIME:|"+ print_date + "|FULL_SENTENCE:|" + sentence + "\n")
    else:
        count = 0
        for sentence in sentences:
            for match in datefinder.find_dates(sentence):
                print_date = pd.to_datetime(pd.Series(match)).dt.strftime('%d/%m/%Y')
                print("|DATETIME:|"+ print_date + "\n")

# %%
#example functionality
dates_in_sentences2(text_to_sentences(cell_obj.value), True)
# Out:
# 0    |DATETIME:|20/12/2013|FULL_SENTENCE:|2013 – 20...
# dtype: object
# 0    |DATETIME:|20/12/2014|FULL_SENTENCE:|2011 – 20...
# dtype: object
# 0    |DATETIME:|20/12/2011|FULL_SENTENCE:|2008 – 20...
# dtype: object
# 0    |DATETIME:|06/12/2022|FULL_SENTENCE:|2022 Qt 6...
# dtype: object
# 0    |DATETIME:|06/12/2022|FULL_SENTENCE:|2022 Qt 6...
# dtype: object
# 0    |DATETIME:|06/12/2022|FULL_SENTENCE:|2022 Qt 6...
# dtype: object
# 0    |DATETIME:|20/12/2021|FULL_SENTENCE:|2021 Comp...
# dtype: object
# 0    |DATETIME:|07/12/2022|FULL_SENTENCE:|2015 Orac...
# dtype: object
# 0    |DATETIME:|20/01/2015|FULL_SENTENCE:|jan 2015 ...
# dtype: object
# 0    |DATETIME:|20/01/2014|FULL_SENTENCE:|jan 2014 ...
# dtype: object
# 0    |DATETIME:|20/07/2014|FULL_SENTENCE:|jan 2014 ...
# dtype: object
# 0    |DATETIME:|20/08/2013|FULL_SENTENCE:|aug 2013 ...
# dtype: object
# 0    |DATETIME:|20/12/2014|FULL_SENTENCE:|aug 2013 ...
# dtype: object
# 0    |DATETIME:|20/08/2010|FULL_SENTENCE:|aug 2010 ...
# dtype: object
# 0    |DATETIME:|20/02/2011|FULL_SENTENCE:|aug 2010 ...
# dtype: object
# 0    |DATETIME:|20/08/2009|FULL_SENTENCE:|aug 2009 ...
# dtype: object
# 0    |DATETIME:|20/02/2010|FULL_SENTENCE:|aug 2009 ...
# dtype: object
# 0    |DATETIME:|20/04/2022|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/01/2022|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/04/2022|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/11/2021|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/02/2022|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/08/2021|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/02/2022|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/02/2021|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/08/2021|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|19/12/2022|FULL_SENTENCE:|en wegens...
# dtype: object
# 0    |DATETIME:|19/12/2022|FULL_SENTENCE:|en wegens...
# dtype: object
# 0    |DATETIME:|19/12/2022|FULL_SENTENCE:|Implement...
# dtype: object
# 0    |DATETIME:|20/07/2020|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/01/2018|FULL_SENTENCE:| BRANCHE:...
# dtype: object
# 0    |DATETIME:|20/06/2020|FULL_SENTENCE:| BRANCHE:...
# dtype: object
