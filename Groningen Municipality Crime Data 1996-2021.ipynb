# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    #dataset used: https://www.kaggle.com/datasets/megan3/groningen-crime-data-19962021

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### load dataset

# %%
csv_file = pd.read_csv("aangifte-politie_totaal.csv")
df = pd.DataFrame(csv_file)
df.head()
# Out:
#           hoofdgroep       main_group                      aangifte  \
# 0  vermogensdelicten  property crimes                 diefstal auto
# 1  vermogensdelicten  property crimes        diefstal motor/scooter
# 2  vermogensdelicten  property crimes  diefstal bromfiets/snorfiets
# 3  vermogensdelicten  property crimes                diefstal fiets
# 4  vermogensdelicten  property crimes          diefstal af/uit auto
#
#                    subgroup  Year_1996  Year_1997  Year_1998  Year_1999  \
# 0                 theft car        327        428        351        334
# 1  theft motorcycle/scooter         28         30         26         28
# 2               theft moped        438        404        418        560
# 3                theft bike       2842        319       3058       3322
# 4            theft from car       2657       2712       2918       3087
#
#    Year_2000  Year_2001  ...  Year_2012  Year_2013  Year_2014  Year_2015  \
# 0        262        330  ...         67         75         70         63
# 1         19         45  ...         36         31         23         64
# 2        301        271  ...        485        485        454        488
# 3       3512       3098  ...       3272       3605       3291       3549
# 4       3058       3251  ...        905        931        885       1091
#
#    Year_2016  Year_2017  Year_2018  Year_2019  Year_2020  Year_2021
# 0         82         50         43         31         27         17
# 1         27         49         46         14         29         35
# 2        397        332        377        401        317        259
# 3       3408       2363       1982       1983       1446       1809
# 4        948        522        384        478        357        228
#
# [5 rows x 30 columns]

# %% [markdown]
# ### data cleaning

# %%
np.where(pd.isnull(df))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df_transpose = df.transpose()
df_transpose = df_transpose.drop([df_transpose.index[0],df_transpose.index[1], df_transpose.index[2]])
df_transpose.head()
# Out:
#                   0                         1            2           3   \
# subgroup   theft car  theft motorcycle/scooter  theft moped  theft bike
# Year_1996        327                        28          438        2842
# Year_1997        428                        30          404         319
# Year_1998        351                        26          418        3058
# Year_1999        334                        28          560        3322
#
#                        4                   5                6            7   \
# subgroup   theft from car  theft from company  theft from home  shoplifting
# Year_1996            2657                 157             3162         1094
# Year_1997            2712                1559             2908          982
# Year_1998            2918                1761             2787         1188
# Year_1999            3087                1481              281         1241
#
#                       8                              9   \
# subgroup   pickpocketing  robbery (including bag theft)
# Year_1996            295                            241
# Year_1997            193                            217
# Year_1998            387                            227
# Year_1999            375                            271
#
#                               10              11         12  \
# subgroup   other property crimes  abuse/violence  sex crime
# Year_1996                     28             780        137
# Year_1997                   3229             870        135
# Year_1998                   2983             926        117
# Year_1999                   3206             894         93
#
#                                 13                           14
# subgroup   theft/human trafficking  destruction property damage
# Year_1996                      256                         2014
# Year_1997                      246                         2183
# Year_1998                      302                         2428
# Year_1999                      305                         2244

# %%
headers = df_transpose.iloc[0].values
df_transpose.columns = headers
df_transpose = df_transpose.drop(df_transpose.index[0])
df_transpose.head()
# Out:
#           theft car theft motorcycle/scooter theft moped theft bike  \
# Year_1996       327                       28         438       2842
# Year_1997       428                       30         404        319
# Year_1998       351                       26         418       3058
# Year_1999       334                       28         560       3322
# Year_2000       262                       19         301       3512
#
#           theft from car theft from company theft from home shoplifting  \
# Year_1996           2657                157            3162        1094
# Year_1997           2712               1559            2908         982
# Year_1998           2918               1761            2787        1188
# Year_1999           3087               1481             281        1241
# Year_2000           3058               1852            2279        1169
#
#           pickpocketing robbery (including bag theft) other property crimes  \
# Year_1996           295                           241                    28
# Year_1997           193                           217                  3229
# Year_1998           387                           227                  2983
# Year_1999           375                           271                  3206
# Year_2000           383                           248                  3037
#
#           abuse/violence sex crime theft/human trafficking  \
# Year_1996            780       137                     256
# Year_1997            870       135                     246
# Year_1998            926       117                     302
# Year_1999            894        93                     305
# Year_2000            975       140                     386
#
#           destruction property damage
# Year_1996                        2014
# Year_1997                        2183
# Year_1998                        2428
# Year_1999                        2244
# Year_2000                        2249

# %%
# simplify the transposed dataset
df_transpose = df_transpose.reset_index()
df_transpose = df_transpose.join(df_transpose['index'].str.split('_', 1, expand=True).rename(columns={0:'Years', 1:'Jaar'}))
df_transpose.drop(columns=['Years', 'index'], axis=1, inplace=True)
first_column = df_transpose.pop('Jaar')
df_transpose.insert(0, 'Year', first_column)
df_transpose = df_transpose.astype('int')
# Out:
# C:\Users\alexd\AppData\Local\Temp\ipykernel_4560\1258864247.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_transpose = df_transpose.join(df_transpose['index'].str.split('_', 1, expand=True).rename(columns={0:'Years', 1:'Jaar'}))

# %%
df_transpose.head()
# Out:
#    Year  theft car  theft motorcycle/scooter  theft moped  theft bike  \
# 0  1996        327                        28          438        2842
# 1  1997        428                        30          404         319
# 2  1998        351                        26          418        3058
# 3  1999        334                        28          560        3322
# 4  2000        262                        19          301        3512
#
#    theft from car  theft from company  theft from home  shoplifting  \
# 0            2657                 157             3162         1094
# 1            2712                1559             2908          982
# 2            2918                1761             2787         1188
# 3            3087                1481              281         1241
# 4            3058                1852             2279         1169
#
#    pickpocketing  robbery (including bag theft)  other property crimes  \
# 0            295                            241                     28
# 1            193                            217                   3229
# 2            387                            227                   2983
# 3            375                            271                   3206
# 4            383                            248                   3037
#
#    abuse/violence  sex crime  theft/human trafficking  \
# 0             780        137                      256
# 1             870        135                      246
# 2             926        117                      302
# 3             894         93                      305
# 4             975        140                      386
#
#    destruction property damage
# 0                         2014
# 1                         2183
# 2                         2428
# 3                         2244
# 4                         2249

# %%
df_transpose.describe()
# Out:
#               Year   theft car  theft motorcycle/scooter  theft moped  \
# count    26.000000   26.000000                 26.000000    26.000000
# mean   2008.500000  159.961538                 30.384615   365.346154
# std       7.648529  124.587152                 12.185489    86.701761
# min    1996.000000   17.000000                 13.000000   188.000000
# 25%    2002.250000   67.750000                 23.250000   312.500000
# 50%    2008.500000  106.000000                 28.000000   351.500000
# 75%    2014.750000  283.000000                 34.250000   414.500000
# max    2021.000000  428.000000                 64.000000   560.000000
#
#         theft bike  theft from car  theft from company  theft from home  \
# count    26.000000       26.000000           26.000000        26.000000
# mean   2881.769231     1533.576923          740.923077      1263.807692
# std     795.686738     1010.707680          593.331336       822.015816
# min     319.000000      103.000000          150.000000       137.000000
# 25%    2799.250000      890.000000          346.500000       668.000000
# 50%    3148.000000     1272.000000          414.500000      1187.500000
# 75%    3332.500000     2595.500000         1241.750000      1601.000000
# max    3829.000000     3251.000000         1852.000000      3162.000000
#
#        shoplifting  pickpocketing  robbery (including bag theft)  \
# count    26.000000      26.000000                      26.000000
# mean    938.692308     398.730769                     133.538462
# std     228.652709     145.681998                      76.237120
# min     113.000000      84.000000                      23.000000
# 25%     862.000000     301.750000                      60.000000
# 50%     950.000000     410.500000                     132.000000
# 75%    1073.250000     484.250000                     198.000000
# max    1241.000000     687.000000                     271.000000
#
#        other property crimes  abuse/violence   sex crime  \
# count               26.00000       26.000000   26.000000
# mean              2447.00000      887.307692   99.115385
# std                919.63558      128.993882   19.279682
# min                 28.00000      524.000000   68.000000
# 25%               2087.75000      867.750000   88.250000
# 50%               2709.50000      928.000000   97.500000
# 75%               3023.50000      957.000000  107.250000
# max               3544.00000     1103.000000  140.000000
#
#        theft/human trafficking  destruction property damage
# count                26.000000                    26.000000
# mean                456.961538                  1716.615385
# std                  99.096511                   675.941008
# min                 246.000000                   124.000000
# 25%                 425.000000                  1569.500000
# 50%                 469.000000                  1906.500000
# 75%                 528.750000                  2204.750000
# max                 612.000000                  2442.000000

# %%
# normalize the transposed data set
df_normalized = df_transpose.copy(deep=True)
s0 = df_normalized.iloc[:,1:]
df_normalized.iloc[:,1:] = (s0 - s0.mean()) / (s0.max() - s0.min())
df_normalized.head()
# Out:
#    Year  theft car  theft motorcycle/scooter  theft moped  theft bike  \
# 0  1996   0.406420                 -0.046757     0.195306   -0.011330
# 1  1997   0.652162                 -0.007541     0.103908   -0.730134
# 2  1998   0.464814                 -0.085973     0.141543    0.050208
# 3  1999   0.423451                 -0.046757     0.523263    0.125422
# 4  2000   0.248269                 -0.223228    -0.172974    0.179553
#
#    theft from car  theft from company  theft from home  shoplifting  \
# 0        0.356869           -0.343081         0.627502     0.137684
# 1        0.374340            0.480656         0.543535     0.038393
# 2        0.439779            0.599340         0.503535     0.221017
# 3        0.493463            0.434828        -0.324895     0.268003
# 4        0.484251            0.652807         0.335601     0.204173
#
#    pickpocketing  robbery (including bag theft)  other property crimes  \
# 0      -0.172024                       0.433313              -0.687998
# 1      -0.341179                       0.336538               0.222412
# 2      -0.019454                       0.376861               0.152446
# 3      -0.039355                       0.554280               0.215870
# 4      -0.026088                       0.461538               0.167804
#
#    abuse/violence  sex crime  theft/human trafficking  \
# 0       -0.185333   0.526175                -0.549075
# 1       -0.029892   0.498397                -0.576398
# 2        0.066826   0.248397                -0.423392
# 3        0.011558  -0.084936                -0.415195
# 4        0.151455   0.567842                -0.193884
#
#    destruction property damage
# 0                     0.128294
# 1                     0.201201
# 2                     0.306896
# 3                     0.227517
# 4                     0.229674

# %% [markdown]
# ### exploratory data visualisations

# %%
plt.figure(figsize=(12, 5))
for i in range(14):
    plt.plot(df_transpose['Year'], df_transpose.iloc[:,i+1],color =np.random.rand(3,)) 
plt.axvline(x= 2020, color='red', linestyle='--', label='Covid-19 pandemic start')
plt.title("Crime occurences over time")
plt.xticks(rotation=45, ha='right')
plt.xlabel("Years")
plt.ylabel("Amount of occurences")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 5))
for i in range(14):
    plt.plot(df_normalized['Year'], df_normalized.iloc[:,i+1],color =np.random.rand(3,))     
plt.axvline(x= 2020, color='red', linestyle='--', label='Covid-19 pandemic start')
plt.title("Crime (normalized) over time")
plt.xticks(rotation=45, ha='right')
plt.xlabel("Years")
plt.ylabel("normalized occurences")
plt.legend()
plt.show()

# %%
corr = df_normalized.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df_normalized.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df_normalized.columns)
ax.set_yticklabels(df_normalized.columns)
plt.title("correlation between different types of crime for 1996 to 2021")
plt.show()

# %%
def corr_sig(df):
    p_matrix = np.zeros(shape=(df.shape[1],df.shape[1]))
    for col in df.columns:
        for col2 in df.drop(col,axis=1).columns:
            _ , p = stats.pearsonr(df[col],df[col2])
            p_matrix[df.columns.to_list().index(col),df.columns.to_list().index(col2)] = p
    return p_matrix

def plot_cor_matrix(corr, mask):
    f, ax = plt.subplots(figsize=(9, 6))
    sns.heatmap(corr, ax=ax,
                mask=mask,
                annot=True, vmin=-1, vmax=1, center=0,
                cmap='coolwarm', linewidths=0.5, linecolor='grey')
    plt.title("correlation between different types of crime for 1996 to 2021 in Groningen (p-value <0.05)")

corr = df_normalized.corr()                           
p_values = corr_sig(df_normalized)                  
mask = np.invert(np.tril(p_values<0.05))  
plot_cor_matrix(corr,mask)

# %%
# add a column which is the mean of the other normalized dataframe columns.
mean = df_normalized.iloc[:, 1:].mean(axis=1)
df_normalized = df_normalized.assign(mean=mean)

plt.figure(figsize=(12, 5))
plt.plot(df_normalized['Year'], df_normalized['mean'],color = 'red')     
plt.axvline(x= 2020, color='red', linestyle='--', label='Covid-19 pandemic start')
plt.axhline(y= 0, color='blue', linestyle='--', label='no change in crime rate')

plt.title("Crime (normalized mean) over time")
plt.xticks(rotation=45, ha='right')
plt.xlabel("Years")
plt.ylabel("normalized occurences")
plt.legend()
plt.show()

# %% [markdown]
# ### building the model
# Im using a Multivariate LSTM Model
#  -> https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

# %%
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
# split into train and test sets
df = array(df_normalized['mean'])

#scaler = MinMaxScaler(feature_range=(0, 1))
#df.array.reshape(-1, 1)
#dataset = scaler.fit_transform(df)

train_ind = int(len(df)*0.67)
train = df[:train_ind]
test = df[train_ind:]
print(len(train), len(test))
# Out:
# 17 9

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=2):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

look_back = 2
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 14/14 - 1s - loss: 0.0115 - 1s/epoch - 104ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.0099 - 26ms/epoch - 2ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.0087 - 33ms/epoch - 2ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.0080 - 32ms/epoch - 2ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.0075 - 28ms/epoch - 2ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.0071 - 45ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.0069 - 31ms/epoch - 2ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.0068 - 33ms/epoch - 2ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.0067 - 29ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.0066 - 27ms/epoch - 2ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.0066 - 27ms/epoch - 2ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.0065 - 26ms/epoch - 2ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.0065 - 26ms/epoch - 2ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.0064 - 26ms/epoch - 2ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.0064 - 27ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.0064 - 26ms/epoch - 2ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.0063 - 27ms/epoch - 2ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.0063 - 29ms/epoch - 2ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.0062 - 27ms/epoch - 2ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.0061 - 26ms/epoch - 2ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.0061 - 28ms/epoch - 2ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.0060 - 27ms/epoch - 2ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.0060 - 26ms/epoch - 2ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.0059 - 23ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.0059 - 28ms/epoch - 2ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.0058 - 24ms/epoch - 2ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.0058 - 26ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.0057 - 28ms/epoch - 2ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.0057 - 23ms/epoch - 2ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.0057 - 23ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.0056 - 25ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.0055 - 24ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.0055 - 23ms/epoch - 2ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.0054 - 24ms/epoch - 2ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.0054 - 23ms/epoch - 2ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.0053 - 24ms/epoch - 2ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.0053 - 27ms/epoch - 2ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.0053 - 25ms/epoch - 2ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.0052 - 25ms/epoch - 2ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.0051 - 25ms/epoch - 2ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.0051 - 23ms/epoch - 2ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.0051 - 25ms/epoch - 2ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.0050 - 24ms/epoch - 2ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.0050 - 24ms/epoch - 2ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.0049 - 25ms/epoch - 2ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.0049 - 25ms/epoch - 2ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.0050 - 26ms/epoch - 2ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.0048 - 23ms/epoch - 2ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.0048 - 26ms/epoch - 2ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.0047 - 27ms/epoch - 2ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.0047 - 24ms/epoch - 2ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.0046 - 25ms/epoch - 2ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.0046 - 25ms/epoch - 2ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.0046 - 31ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.0045 - 23ms/epoch - 2ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.0045 - 24ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.0044 - 22ms/epoch - 2ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.0045 - 25ms/epoch - 2ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.0045 - 24ms/epoch - 2ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.0043 - 23ms/epoch - 2ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.0043 - 21ms/epoch - 2ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.0043 - 24ms/epoch - 2ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.0043 - 24ms/epoch - 2ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.0043 - 22ms/epoch - 2ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.0042 - 25ms/epoch - 2ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.0042 - 28ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.0041 - 25ms/epoch - 2ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.0041 - 25ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.0041 - 25ms/epoch - 2ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.0040 - 26ms/epoch - 2ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.0040 - 29ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.0040 - 24ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.0040 - 26ms/epoch - 2ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.0041 - 26ms/epoch - 2ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.0039 - 27ms/epoch - 2ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.0039 - 26ms/epoch - 2ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.0039 - 23ms/epoch - 2ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.0039 - 24ms/epoch - 2ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.0039 - 24ms/epoch - 2ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.0039 - 24ms/epoch - 2ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.0038 - 24ms/epoch - 2ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.0039 - 25ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.0038 - 24ms/epoch - 2ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.0038 - 41ms/epoch - 3ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.0038 - 25ms/epoch - 2ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.0038 - 25ms/epoch - 2ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.0038 - 25ms/epoch - 2ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.0038 - 24ms/epoch - 2ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.0038 - 22ms/epoch - 2ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.0037 - 24ms/epoch - 2ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.0038 - 24ms/epoch - 2ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.0037 - 24ms/epoch - 2ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.0038 - 22ms/epoch - 2ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.0037 - 27ms/epoch - 2ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.0037 - 32ms/epoch - 2ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.0037 - 31ms/epoch - 2ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.0037 - 27ms/epoch - 2ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.0037 - 25ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.0037 - 33ms/epoch - 2ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.0037 - 23ms/epoch - 2ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
print(trainY[0])
print('------')
print(trainPredict[:,0])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY, trainPredict[:,0]))
trainScore
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY, testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 20ms/step
# 0.20285618555454085
# ------
# [ 0.07432386  0.14158346  0.14537919  0.15596113  0.12753956  0.07996793
#   0.08882955  0.10531704  0.05519023  0.03807677  0.05473709  0.01323833
#  -0.02288127 -0.01175672]
# Train Score: 0.06 RMSE
# Test Score: 0.10 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(df)
trainPredictPlot = np.zeros((len(trainPredict), 1))
trainPredictPlot[0:len(trainPredict)+look_back] = trainPredict[0:]
print(len(trainPredictPlot))
# Out:
# 14

# %%
testPredictPlot = np.empty_like(df)
testPredictPlot = np.full((len(df), 1), np.nan)
testPredictPlot[len(trainPredict)+look_back+3:len(df)-1, :] = testPredict
print(len(testPredict))
print(len(df))
# Out:
# 6
# 26

# %%
plt.figure(figsize=(12, 5))

plt.title("Crime (normalized mean) over time")
plt.xticks(rotation=45, ha='right')
plt.xlabel("Years")
plt.ylabel("normalized occurences")

plt.axvline(x= 24, color='red', linestyle='--', label='Covid-19 pandemic start')
plt.axhline(y= 0, color='blue', linestyle='--', label='no change in crime rate')

plt.plot(df)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
